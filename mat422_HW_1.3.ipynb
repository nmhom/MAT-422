# %% [markdown]
# <a href="https://colab.research.google.com/github/nmhom/MAT-422/blob/main/mat422_HW_1.3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW 1.3

# %%
import numpy as np
from scipy.linalg import null_space

# %% [markdown]
# ## 1.3.1 QR Decomposition
# QR factorization splits a matrix into an orthogonal matrix Q and an upper triangluar matrix R: $$A = QR$$ where Q is an orthogonal matrix and R is an upper triangluar matrix. This section demonstrates the core components of QR Decomposition: verifying that QR reconstructs A, and verifying that Q is orthonormal and R is upper triangular.

# %% [markdown]
# ### Verify that QR reconstructs A, and Q is orthonormal

# %% [markdown]
# ### Demonstrate that R is upper triangular

# %% [markdown]
# ## 1.3.2 Least-Squares Problem
#
# The least-squares problem is finding the solution x that minimizes the difference between Ax and b. This problem occurs when there is a system Ax = b that doesn't have an exact solution, usually because there are more equations than unknowns.

# %% [markdown]
# ### Find the x that makes the error between Ax and b as small as possible
#
# **Theoream 1.3.2** Using QR Decomposition: $Rx* = Q^Tb$. $A=QR$ allows us to turn the least-squares problem into a simpler triangular system that can be solved using back substitution.

# %% [markdown]
# ### Calculate $A^TAx$ and $A^Tb$ and set them equal
# **Theorem 1.3.1** Normal Equations - The solution to a least-squares problem satisfies $A^TAx = A^Tb$

# %% [markdown]
# ### Demonstrate the residual/error

# %% [markdown]
# ### Demonstrate that the least-squares residual is orthogonal to the columns of A. If

# %% [markdown]
# ### Demonstrate linear regression as a least-squares problem

# %% [markdown]
# ## 1.3.3 Linear Regression
